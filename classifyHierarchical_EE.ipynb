# %% [markdown]
# # [ **RUN ALWAYS** ] Import, initialize

# %%
import math
import geemap
import ee
import configparser as cp
import io
import ast
import subprocess

from classification import classifyAndAssess
from features import ecological

ee.Initialize(project = 'ee-open-natural-ecosystems')

# %% [markdown]
# Find paths to the home folder and results for this run.

# %%
with open("config.ini", 'r') as f:
    fileContents = f.read()
config = cp.RawConfigParser(allow_no_value = True, interpolation = cp.ExtendedInterpolation())
config.read_file(io.StringIO(fileContents))

configCore = config["CORE"]
homeFolder = configCore.get('assetFolderWithFeatures')
configClassify = config["CLASSIFICATION-TRAIN&PREDICT"]
resColl = configClassify.get('existingPredictionsCollection')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Feature names from saved feature rasters
#
# Read the names of all the features associated with each labeled training point. Verify that the set of features is as intended.
#
# The function `assembleAllExistingFeatureRasters()` in the `generateFeatures` module gathers all relevant rasters from the config-designated folder of EE assets.
# It "manually" reads-in all feature rasters using their generation functions, but with `returnExisting` flag set to `True`.

# %%
namesOfAllFeatures = ecological.assembleAllExistingFeatureRasters('2019').bandNames().getInfo()
print(namesOfAllFeatures)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['A00', 'A01', 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10', 'A11', 'A12', 'A13', 'A14', 'A15', 'A16', 'A17', 'A18', 'A19', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'A40', 'A41', 'A42', 'A43', 'A44', 'A45', 'A46', 'A47', 'A48', 'A49', 'A50', 'A51', 'A52', 'A53', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A60', 'A61', 'A62', 'A63', 'ae_regcode', 'longitude', 'latitude']

# %% [markdown]
# ## Classification
#
# Select the features we will use, choose the classifier and set its parameters.

# %%
selFeatureNames = [
    'A00', 'A01', 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10', 'A11', 'A12', 'A13', 'A14', 'A15',
    'A16', 'A17', 'A18', 'A19', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'A30', 'A31',
    'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'A40', 'A41', 'A42', 'A43', 'A44', 'A45', 'A46', 'A47',
    'A48', 'A49', 'A50', 'A51', 'A52', 'A53', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A60', 'A61', 'A62', 'A63',
    'ae_regcode'] # 'longitude', 'latitude'

cOpts_gbt150 = dict(classifier = "GradientBoostedTrees", numTrees = 150, maxNodes = 500, trainFraction = 0.7)
fOpts_globalModelGbt_agroecolZones = dict(names = selFeatureNames, zonationBasis = "agroecol", zoneEncodingMode = "num")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Classify to predict final labels
#
# Create a folder for the results.

# %%
resFolderAgroecolZonesNum_finalPred = "yearwiseClassify_AgroecolZonesNum_finalPred_fullAoi"
createResFolderCmd = f"earthengine create folder {homeFolder}{resFolderAgroecolZonesNum_finalPred}"
process = subprocess.Popen(createResFolderCmd.split(), stdout=subprocess.PIPE)
folderCreated, error = process.communicate()
print("Result folder creation error (if any):", folderCreated, error)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Result folder creation error (if any): b'Asset projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/yearwiseClassify_AgroecolZonesNum_finalPred_fullAoi already exists.\n' None

# %% [markdown]
# Create an ImageCollection within the results folder to hold the classifier predictions.

# %%
createResCollCmd = f"earthengine create collection {homeFolder}{resFolderAgroecolZonesNum_finalPred}/{resColl}"
process = subprocess.Popen(createResCollCmd.split(), stdout=subprocess.PIPE)
collCreated, errorColl = process.communicate()
print("Result image collection creation error (if any):", collCreated, errorColl)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Result image collection creation error (if any): b'Asset projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/yearwiseClassify_AgroecolZonesNum_finalPred_fullAoi/satEmbed_preds_fullAoiExp_fullModel_tiled already exists.\n' None

# %% [markdown]
# #### Hierarchical classification - using explicit hierarchy

# %% [markdown]
# Run the hierarchical classification year-wise.

# %%
hierarchOpts_exp = dict(coarserLevelLabelColumn = "labelL1", finerLevelLabelColumn = "labelL2")
globalModelGbtBiomesZonesOheRes_heir_master_explicit = classifyAndAssess.trainAndPredictHierarchical_master( \
    hierarchOpts_exp, \
    fOpts_globalModelGbt_agroecolZones, \
    cOpts_gbt150, \
    resultNewFolderName = resFolderAgroecolZonesNum_finalPred, \
    resultNewCollName = resColl, \
    returnExisting = False)
print(globalModelGbtBiomesZonesOheRes_heir_master_explicit.getInfo())
# print(globalModelGbtBiomesZonesOheRes_heir_master_explicit.size())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ====== 2017 ======
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2017 points path
# l0 names & codes: {'nonone': 100, 'one': 200}
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2017  year points asset folder
# ['A00', 'A01', 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10', 'A11', 'A12', 'A13', 'A14', 'A15', 'A16', 'A17', 'A18', 'A19', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'A40', 'A41', 'A42', 'A43', 'A44', 'A45', 'A46', 'A47', 'A48', 'A49', 'A50', 'A51', 'A52', 'A53', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A60', 'A61', 'A62', 'A63', 'ae_regcode'] selected features
# exporting ... 2017 l0
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'agri_open': 1, 'built': 3, 'cultivated_trees': 4, 'forest': 6, 'other': 99, 'water_wetland': 11}
# ['system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'labelL2Num', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2017 nonone
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'bare_rocky': 2, 'dunes': 5, 'other': 99, 'saline_flat': 7, 'savanna_grass': 8, 'savanna_shrub': 9, 'savanna_tree': 10}
# ['labelL2Num', 'system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2017 one
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# ====== 2018 ======
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2018 points path
# l0 names & codes: {'nonone': 100, 'one': 200}
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2018  year points asset folder
# ['A00', 'A01', 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10', 'A11', 'A12', 'A13', 'A14', 'A15', 'A16', 'A17', 'A18', 'A19', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'A40', 'A41', 'A42', 'A43', 'A44', 'A45', 'A46', 'A47', 'A48', 'A49', 'A50', 'A51', 'A52', 'A53', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A60', 'A61', 'A62', 'A63', 'ae_regcode'] selected features
# exporting ... 2018 l0
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'agri_open': 1, 'built': 3, 'cultivated_trees': 4, 'forest': 6, 'other': 99, 'water_wetland': 11}
# ['system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'labelL2Num', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2018 nonone
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'bare_rocky': 2, 'dunes': 5, 'other': 99, 'saline_flat': 7, 'savanna_grass': 8, 'savanna_shrub': 9, 'savanna_tree': 10}
# ['labelL2Num', 'system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2018 one
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# ====== 2019 ======
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2019 points path
# l0 names & codes: {'nonone': 100, 'one': 200}
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2019  year points asset folder
# ['A00', 'A01', 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10', 'A11', 'A12', 'A13', 'A14', 'A15', 'A16', 'A17', 'A18', 'A19', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'A40', 'A41', 'A42', 'A43', 'A44', 'A45', 'A46', 'A47', 'A48', 'A49', 'A50', 'A51', 'A52', 'A53', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A60', 'A61', 'A62', 'A63', 'ae_regcode'] selected features
# exporting ... 2019 l0
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'agri_open': 1, 'built': 3, 'cultivated_trees': 4, 'forest': 6, 'other': 99, 'water_wetland': 11}
# ['system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'labelL2Num', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2019 nonone
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'bare_rocky': 2, 'dunes': 5, 'other': 99, 'saline_flat': 7, 'savanna_grass': 8, 'savanna_shrub': 9, 'savanna_tree': 10}
# ['labelL2Num', 'system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2019 one
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# ====== 2020 ======
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2020 points path
# l0 names & codes: {'nonone': 100, 'one': 200}
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2020  year points asset folder
# ['A00', 'A01', 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10', 'A11', 'A12', 'A13', 'A14', 'A15', 'A16', 'A17', 'A18', 'A19', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'A40', 'A41', 'A42', 'A43', 'A44', 'A45', 'A46', 'A47', 'A48', 'A49', 'A50', 'A51', 'A52', 'A53', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A60', 'A61', 'A62', 'A63', 'ae_regcode'] selected features
# exporting ... 2020 l0
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'agri_open': 1, 'built': 3, 'cultivated_trees': 4, 'forest': 6, 'other': 99, 'water_wetland': 11}
# ['system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'labelL2Num', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2020 nonone
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'bare_rocky': 2, 'dunes': 5, 'other': 99, 'saline_flat': 7, 'savanna_grass': 8, 'savanna_shrub': 9, 'savanna_tree': 10}
# ['labelL2Num', 'system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2020 one
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# ====== 2021 ======
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2021 points path
# l0 names & codes: {'nonone': 100, 'one': 200}
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2021  year points asset folder
# ['A00', 'A01', 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10', 'A11', 'A12', 'A13', 'A14', 'A15', 'A16', 'A17', 'A18', 'A19', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'A40', 'A41', 'A42', 'A43', 'A44', 'A45', 'A46', 'A47', 'A48', 'A49', 'A50', 'A51', 'A52', 'A53', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A60', 'A61', 'A62', 'A63', 'ae_regcode'] selected features
# exporting ... 2021 l0
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'agri_open': 1, 'built': 3, 'cultivated_trees': 4, 'forest': 6, 'other': 99, 'water_wetland': 11}
# ['system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'labelL2Num', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2021 nonone
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'bare_rocky': 2, 'dunes': 5, 'other': 99, 'saline_flat': 7, 'savanna_grass': 8, 'savanna_shrub': 9, 'savanna_tree': 10}
# ['labelL2Num', 'system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2021 one
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# ====== 2022 ======
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2022 points path
# l0 names & codes: {'nonone': 100, 'one': 200}
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2022  year points asset folder
# ['A00', 'A01', 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10', 'A11', 'A12', 'A13', 'A14', 'A15', 'A16', 'A17', 'A18', 'A19', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'A40', 'A41', 'A42', 'A43', 'A44', 'A45', 'A46', 'A47', 'A48', 'A49', 'A50', 'A51', 'A52', 'A53', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A60', 'A61', 'A62', 'A63', 'ae_regcode'] selected features
# exporting ... 2022 l0
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'agri_open': 1, 'built': 3, 'cultivated_trees': 4, 'forest': 6, 'other': 99, 'water_wetland': 11}
# ['system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'labelL2Num', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2022 nonone
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'bare_rocky': 2, 'dunes': 5, 'other': 99, 'saline_flat': 7, 'savanna_grass': 8, 'savanna_shrub': 9, 'savanna_tree': 10}
# ['labelL2Num', 'system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2022 one
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# ====== 2023 ======
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2023 points path
# l0 names & codes: {'nonone': 100, 'one': 200}
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2023  year points asset folder
# ['A00', 'A01', 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10', 'A11', 'A12', 'A13', 'A14', 'A15', 'A16', 'A17', 'A18', 'A19', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'A40', 'A41', 'A42', 'A43', 'A44', 'A45', 'A46', 'A47', 'A48', 'A49', 'A50', 'A51', 'A52', 'A53', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A60', 'A61', 'A62', 'A63', 'ae_regcode'] selected features
# exporting ... 2023 l0
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'agri_open': 1, 'built': 3, 'cultivated_trees': 4, 'forest': 6, 'other': 99, 'water_wetland': 11}
# ['system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'labelL2Num', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2023 nonone
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'bare_rocky': 2, 'dunes': 5, 'other': 99, 'saline_flat': 7, 'savanna_grass': 8, 'savanna_shrub': 9, 'savanna_tree': 10}
# ['labelL2Num', 'system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2023 one
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# ====== 2024 ======
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2024 points path
# l0 names & codes: {'nonone': 100, 'one': 200}
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/sampledFeatures_balanced/pointsWithFeaturesYearwise_2024  year points asset folder
# ['A00', 'A01', 'A02', 'A03', 'A04', 'A05', 'A06', 'A07', 'A08', 'A09', 'A10', 'A11', 'A12', 'A13', 'A14', 'A15', 'A16', 'A17', 'A18', 'A19', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'A40', 'A41', 'A42', 'A43', 'A44', 'A45', 'A46', 'A47', 'A48', 'A49', 'A50', 'A51', 'A52', 'A53', 'A54', 'A55', 'A56', 'A57', 'A58', 'A59', 'A60', 'A61', 'A62', 'A63', 'ae_regcode'] selected features
# exporting ... 2024 l0
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'agri_open': 1, 'built': 3, 'cultivated_trees': 4, 'forest': 6, 'other': 99, 'water_wetland': 11}
# ['system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'labelL2Num', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2024 nonone
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# l1 names & codes: {'bare_rocky': 2, 'dunes': 5, 'other': 99, 'saline_flat': 7, 'savanna_grass': 8, 'savanna_shrub': 9, 'savanna_tree': 10}
# ['labelL2Num', 'system:index', 'A43', 'A00', 'A44', 'A01', 'A45', 'A02', 'A46', 'A03', 'A47', 'A04', 'A48', 'A05', 'A49', 'A06', 'A07', 'A08', 'A09', 'A50', 'A51', 'A52', 'A53', 'A10', 'A54', 'A11', 'A55', 'A12', 'A56', 'A13', 'A57', 'A14', 'A58', 'A15', 'A59', 'A16', 'A17', 'A18', 'A19', 'A60', 'A61', 'A62', 'A63', 'A20', 'A21', 'A22', 'A23', 'A24', 'A25', 'A26', 'A27', 'A28', 'A29', 'random', 'A30', 'A31', 'A32', 'A33', 'A34', 'A35', 'A36', 'A37', 'A38', 'A39', 'ae_regcode', 'A40', 'A41', 'A42'] ptsWithFineLevelLabelsPrepped prop names
# exporting ... 2024 one
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# hierarchy mode explicit
# 111414

# %% [markdown]
# ##### Combine hierarchical probabilities
#
# Combine each year's hierarchical probabilities using explicit probability hierarchy, to get year-wise probabilistic classification for all classes.

# %%
combinedOutputs = classifyAndAssess.annualHierarchicalPredictions(
    resultNewFolderName = resFolderAgroecolZonesNum_finalPred, resultNewCollName = resColl)
print(combinedOutputs.getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/yearwiseClassify_AgroecolZonesNum_finalPred_fullAoi/satEmbed_preds_fullAoiExp_fullModel_tiled predHeirProbsColl id
# exporting expHierMult for year 2017...
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# exporting expHierMult for year 2018...
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# exporting expHierMult for year 2019...
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# exporting expHierMult for year 2020...
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# exporting expHierMult for year 2021...
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# exporting expHierMult for year 2022...
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# exporting expHierMult for year 2023...
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# exporting expHierMult for year 2024...
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
# {'type': 'ImageCollection', 'bands': [], 'version': 1762696831239848, 'id': 'projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/yearwiseClassify_AgroecolZonesNum_finalPred_fullAoi/satEmbed_preds_fullAoiExp_fullModel_tiled', 'features': [{'type': 'Image', 'bands': [{'id': 'prob_nonone', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [12532, 16744], 'crs': 'EPSG:24343', 'crs_transform': [10, 0, -125310, 0, -10, 2500010]}, {'id': 'prob_one', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [12532, 16744], 'crs': 'EPSG:24343', 'crs_transform': [10, 0, -125310, 0, -10, 2500010]}, {'id': 'top1LabelNum', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [12532, 16744], 'crs': 'EPSG:24343', 'crs_transform': [10, 0, -125310, 0, -10, 2500010]}], 'version': 1762155299556547, 'id': 'projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/yearwiseClassify_AgroecolZonesNum_finalPred_fullAoi/satEmbed_preds_fullAoiExp_fullModel_tiled/prediction_l0_2017_tile_-1_4', 'properties': {'nodeName': 'l0', 'numClassifierTrees': 150, 'year': '2017', 'zoneEncoding': 'num', 'numMaxNodes': 500, 'classifierUsed': 'GradientBoostedTrees', 'fractionOfPointsForTrain': 0.7, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[70.14092713195946, 22.53572596682254], [70.1408486400842, 22.535813653731232], [68.92786705210077, 22.494519192700803], [68.93606183040131, 22.306421521501196], [68.94416579523781, 22.118406462057088], [68.95218331338769, 21.930384397598043], [68.96011484026018, 21.74235517958447], [68.96796092223545, 21.554318941169427], [68.97572210570188, 21.366275826272435], [68.9833987551358, 21.178225793976825], [68.99099505531385, 20.99007898655051], [70.19157503276008, 21.028348997566976], [70.18548039044657, 21.21687078270643], [70.1793210990619, 21.40529675948346], [70.17309406822758, 21.593716756223355], [70.16679875104421, 21.782130867900825], [70.1604347822705, 21.970538788641043], [70.15400188748755, 22.158940757448956], [70.14749942887316, 22.347336455505662], [70.14092713195946, 22.53572596682254]]}, 'classifierSchemaFeaturesUsed': 'A00,A01,A02,A03,A04,A05,A06,A07,A08,A09,A10,A11,A12,A13,A14,A15,A16,A17,A18,A19,A20,A21,A22,A23,A24,A25,A26,A27,A28,A29,A30,A31,A32,A33,A34,A35,A36,A37,A38,A39,A40,A41,A42,A43,A44,A45,A46,A47,A48,A49,A50,A51,A52,A53,A54,A55,A56,A57,A58,A59,A60,A61,A62,A63,ae_regcode', 'system:asset_size': 451330069, 'system:index': 'prediction_l0_2017_tile_-1_4'}}, {'type': 'Image', 'bands': [{'id': 'prob_nonone', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [19610, 50002], 'crs': 'EPSG:24343', 'crs_transform': [10, 0, -196090, 0, -10, 3000010]}, {'id': 'prob_one', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [19610, 50002], 'crs': 'EPSG:24343', 'crs_transform': [10, 0, -196090, 0, -10, 3000010]}, {'id': 'top1LabelNum', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [19610, 50002], 'crs': 'EPSG:24343', 'crs_transform': [10, 0, -196090, 0, -10, 3000010]}], 'version': 1762156920565478, 'id': 'projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/yearwiseClassify_AgroecolZonesNum_finalPred_fullAoi/satEmbed_preds_fullAoiExp_fullModel_tiled/prediction_l0_2017_tile_-1_5', 'properties': {'nodeName': 'l0', 'numClassifierTrees': 150, 'year': '2017', 'zoneEncoding': 'num', 'numMaxNodes': 500, 'classifierUsed': 'GradientBoostedTrees', 'fractionOfPointsForTrain': 0.7, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[68.08037869455974, 25.549745014840585], [68.11223030205105, 24.989423583439898], [68.1431389452784, 24.4290229867221], [68.17312277298714, 23.868545275097357], [68.20219957562472, 23.307992239157713], [68.24415487877512, 22.466935819512244], [70.14105032057718, 22.535549578485927], [70. ...

# %% [markdown]
# #### Find max probability timeseries label sequence
#
# Using the year-wise probabilistic classifications above along with region-wise class transition probability matrices in `aer_hmm_parameters.ini`, find the optimal label sequence (Viterbi decoding) for 7 years (2018 - 2024) by statistically mitigating spurious class transitions between years.
#
# This step frames the annual landcover classification problem as a hidden Markov model (HMM) and uses Viterbi decoding to arrive at the best label sequence.

# %%
classifyAndAssess.optimalTimeseriesLabels(resultFolderName = resFolderAgroecolZonesNum_finalPred)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ------ Step 1 ------
# ------ Steps 2-7 ------
# 7 stepsDone
# projects/ee-open-natural-ecosystems/assets/one10m/finish2025_satEmbedTs/yearwiseClassify_AgroecolZonesNum_finalPred_fullAoi/satEmbed_preds_fullAoiExp_fullModel_tiled/optLabelSeqInBands result export coll
# Total tiles 24
# Started Task:  1
# Started Task:  2
# Started Task:  3
# Started Task:  4
# Started Task:  5
# Started Task:  6
# Started Task:  7
# Started Task:  8
# Started Task:  9
# Started Task:  10
# Started Task:  11
# Started Task:  12
# Started Task:  13
# Started Task:  14
# Started Task:  15
# Started Task:  16
# Started Task:  17
# Started Task:  18
# Started Task:  19
# Started Task:  20
# Started Task:  21
# Started Task:  22
# Started Task:  23
# Started Task:  24
